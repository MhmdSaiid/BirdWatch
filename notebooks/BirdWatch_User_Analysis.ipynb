# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
import numpy as np
from scipy.spatial import distance
from collections import Counter

# %%
notes_file = '../data/notes-00000.tsv'
ratings_file = '../data/ratings-00000.tsv'
hydrated_file = '../data/idtweetVALUES.jsonl'

# %%
notes_df = pd.read_csv(notes_file, delimiter='\t')

hydrated_Tweets=pd.read_json(hydrated_file, lines=True)

#merge notes with hydrated file
notes_text_df = pd.merge(notes_df, hydrated_Tweets, left_on='tweetId', right_on='id')
notes_text_df_en = notes_text_df[notes_text_df['lang']=='en']

# %%
# aggregate with noteId
agg_noted_df = notes_text_df_en.groupby('tweetId').agg({'noteId':'count'})
# get tweets having more than two notes
TweetsMoreThanTwoNoters = list(agg_noted_df[agg_noted_df['noteId']>1].index)
notes_df_two_noters = notes_text_df_en[notes_text_df_en.tweetId.apply(lambda x: True if x in TweetsMoreThanTwoNoters else False)]
notes_df_two_noters = notes_df_two_noters.reset_index(drop=True)

# %%
# pivot table
notes_df_two_noters=notes_df_two_noters.drop_duplicates(subset=['participantId','tweetId'])
pivot_table = notes_df_two_noters.pivot(index='participantId',columns='tweetId',values='classification')

d={'MISINFORMED_OR_POTENTIALLY_MISLEADING':1,'NOT_MISLEADING':1,np.nan:0}
pivot_table=pivot_table.applymap(lambda x: d[x])

users = pivot_table.to_numpy()

# %%
#compute dot product between users
max_=-1
max_ind=-1
closest_users = {}
for i in tqdm(range(users.shape[0])[:]):
    sims = {ind:np.dot(users[i],other_usr) for ind,other_usr in enumerate(users) if ind!=i}
    sims = {k:v for (k,v) in sims.items() if v}
    closest_users[i]=sims
    if sims:
        max_similarity = max(sims.values())
        if max_similarity > max_:
            max_ = max_similarity
            max_ind  = (i,max(sims,key=sims.get))
# Out:
# 100%|██████████| 1550/1550 [00:22<00:00, 67.78it/s]

# %%
def two_users_with_max_tweets_func(x):
    return max(x[1].values()) if x[1] else -1

user_1=max(closest_users.items(),key=two_users_with_max_tweets_func)[0]

user_2 = max(closest_users[user_1],key=closest_users[user_1].get)

# %%
# users with most common tweets
df1 = notes_text_df_en[notes_text_df_en.participantId==pivot_table.index[user_1]]
df2 = notes_text_df_en[notes_text_df_en.participantId==pivot_table.index[user_2]]


df1 = notes_df_two_noters[notes_df_two_noters.participantId==pivot_table.index[user_1]]
df2 = notes_df_two_noters[notes_df_two_noters.participantId==pivot_table.index[user_2]]


common = pd.merge(df1,df2,on='tweetId',how='inner')

common_text = pd.merge(common,hydrated_Tweets,left_on='tweetId', right_on='id',how='inner')

for index,row in common_text.iterrows():
    print(f'Tweet ID: {row.tweetId}')
    print(f'Tweet Text:\n{row.full_text}')
    print()
    print(f'User #1 Classification: {row.classification_x}')
    print(f'User #1 Note: {row.summary_x}')
    print()
    print(f'User #2 Classification: {row.classification_y}')
    print(f'User #2 Note: {row.summary_y}')
    print('\n\n\n')
# Out:
# Tweet ID: 1354889772901277703
# Tweet Text:
# You heard it here first:
#
# If we do not CONTAIN Trump by impeachment or indictment, in a few months he will start to run a shadow government from Mar-a-Lago and at least a dozen governors will start to take their orders from HIM.
#
# He will claim he is the legitimate President &amp;
#
# User #1 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #1 Note: She is speculative at best. And she makes claims that are over the top in their fearmongering.
#
# User #2 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #2 Note: Trump is not running a shadow government from Mar-a-Lago. He?s playing golf and set up the office of the FORMER president. This tweet is inciting fear based on fantasy.     https://www.cbsnews.com/amp/news/office-of-the-former-president-trump-florida/
#
#
#
#
# Tweet ID: 1354608406548656130
# Tweet Text:
# Republican members of Congress don’t want consequences for white supremacy or insurrection against the United States because their political strategy is to embrace white supremacists and the scepter of the Confederacy to get power in the first place. https://t.co/WykDsPUnCI
#
# User #1 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #1 Note: In addition to her use of ad hominem fallacies, she engages in language and allegations that are below the office of a congressional representative. Also this video: https://www.realclearpolitics.com/video/2020/10/10/supercut_president_trump_condemns_white_supremacy.html
#
# User #2 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #2 Note: This is patently false. Republicans consistently denounce white supremacy and the attack on the capital.     https://www.dallasnews.com/news/politics/2021/01/06/as-pro-trump-mob-storms-us-capitol-texas-republicans-denounce-violence/?outputType=amp
#
#
#
#
# Tweet ID: 1355313484758573056
# Tweet Text:
# This confirms EXACTLY what I have been saying: Former KGB Spy Claims Russia Groomed Trump to Be an Asset for 40 Years, Felt He Was 'Vulnerable Intellectually, and Psychologically' https://t.co/F7ELGwqKxo via @mediaite
#
# User #1 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #1 Note: Confirmation Bias fallacy. Plus he?s relying on a former KGB spy as a credible source. Plus this: https://thefederalist.com/2020/10/06/breaking-dni-declassifies-handwritten-notes-from-john-brennan-2016-cia-referral-on-clinton-campaigns-collusion-operation/
#
# User #2 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #2 Note: Russia did not groom Trump to be a KGB agent. No one could have predicted 40 years ago that Trump would become president.     https://www.cato.org/publications/commentary/stop-saying-donald-trump-colluded-russia
#
#
#
#
# Tweet ID: 1355134457666265090
# Tweet Text:
# The biggest difference is, of course, the tone from the top -- Biden is taking this very seriously, is wearing a mask, is begging Americans to wear a mask. Trump of course did none of that.
#
# But, for a range of reasons, the on-the-ground vaccination plans so far are similar.
#
# User #1 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #1 Note: Trump did actually recommend that people wear masks and said so frequently. https://youtu.be/bXjZP0uoWLs
#
# User #2 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #2 Note:   Trump took the pandemic seriously, holding numerous press conferences and taking questions from the press. Trump encouraged people to wear masks and he himself wore a mask while visiting places such as Walter Reed and Ford.     https://apnews.com/article/7651589ac439646e5cf873d021f1f4b6
#
#
#
#
# Tweet ID: 1355595766996365317
# Tweet Text:
# @AnaCabrera The GOP is the domestic terrorism party.
#
# User #1 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #1 Note: No. The GOP is not a terrorist organization. This is inflammatory language that is based solely in his opinion and is incredibly damaging to the larger discourse. We have very specific definitions of terrorist organizations. and having a different political opinion isn't it. https://www.brookings.edu/blog/order-from-chaos/2018/10/29/when-to-call-a-terrorist-a-terrorist/
#
# User #2 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #2 Note: The GOP is the party of law &amp; order, not domestic terrorism. Republicans have not only denounced the attack on the capital but the riots as well.     https://www.cbs7.com/2021/01/06/rep-august-pfluger-condemns-violence-at-us-capitol-as-protests-continue/
#
#
#
#
# Tweet ID: 1356007077416726531
# Tweet Text:
# This, but with pineapple https://t.co/jOgn9f0GIn
#
# User #1 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #1 Note: I agree w Toad on this. It?s a culinary train wreck and cannot stand.
#
# User #2 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #2 Note: Pineapple does not belong on pizza. Even Chef Ramsay thinks pineapple on pizza is a travesty.     https://www.washingtonpost.com/news/voraciously/wp/2019/04/23/pineapple-on-pizza-is-easy-to-hate-at-least-in-theory/?outputType=amp
#
#
#
#
# Tweet ID: 1355985174631227398
# Tweet Text:
# @Noindoctrinate @Cernovich @JackPosobiec Except Lincoln project are Republicans
#
# User #1 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #1 Note: The Lincoln Project is made of of neocon creeps who?ve become trolls and no longer belong to a political party. Given their issues, the LP should be shunned by all intelligent people.
#
# User #2 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #2 Note: Actually the founder is a registered Democrat.     https://thehill.com/homenews/news/530393-longtime-gop-strategist-steve-schmidt-announces-hes-registering-democrat?amp
#
#
#
#
# Tweet ID: 1356061160429285376
# Tweet Text:
# Mac and cheese is terrible
#
# User #1 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #1 Note: While I also agree that birbs aren't real, I know for a fact that mac and cheese is actually the best option. https://www.foodnetwork.com/recipes/ina-garten/mac-and-cheese-recipe2-1945401
#
# User #2 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #2 Note: Mac &amp; Cheese is so awesome Michael Bolton wrote a song about the dish    https://amp.usatoday.com/amp/5804628002
#
#
#
#
# Tweet ID: 1356096800613142528
# Tweet Text:
# Trump attempted a coup, which ended with a cop-killing mob assaulting the Capitol.
#
# Went a little bit beyond “theater.” https://t.co/D8evjiutOB
#
# User #1 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #1 Note: No. Trump did not attempt a coup. No. He did not trigger a riot. As we are now seeing, the events at the Capitol were planned in advance by bad actors. There is video of non-Trump agitators participating all over the Capitol. https://www.centerforsecuritypolicy.org/2021/01/13/covert-cadre-what-i-saw-leading-up-to-the-us-capitol-attack/
#
# User #2 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #2 Note: Trump did not attempt a coup. He participated in a peaceful transition of power, not a coup.     https://world.wng.org/content/trump_calls_for_peaceful_transition_of_power
#
#
#
#
# Tweet ID: 1357025133219700737
# Tweet Text:
# This is the latest manipulative take on the right.
#
# They are manipulating the fact that most people don’t know the layout the Capitol complex.
#
# We were all on the Capitol complex - the attack wasn’t just on the dome.
#
# The bombs Trump supporters planted surrounded our offices too. https://t.co/jI18e0XRrd
#
# User #1 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #1 Note: To date, the FBI has not determined who planted the bombs at the RNC/DNC offices: https://www.11alive.com/article/news/national/capitol-riots/capitol-riot-pipe-bomb-suspect-reward-fbi-atf-us-capitol/65-cdaace64-86d9-44a6-821b-1ebf8cdcb979     Her rhetorical style continues to play on emotions.
#
# User #2 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #2 Note: The FBI has yet to identify a suspect who placed bombs at the DNC &amp; RNC.    https://amp.cnn.com/cnn/2021/01/29/politics/washington-pipe-bombs-dnc-rnc/index.html
#
#
#
#
# Tweet ID: 1357388958930530307
# Tweet Text:
# Finishing the job of delivering $2,000 in direct relief to the hardest-hit Americans — that’s the American Rescue Plan. https://t.co/eWP0Dg4cuR
#
# User #1 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #1 Note: So he lied to the people of GA during the Run off election. And he ran on it. Thus far, another promise not kept. https://www.businessinsider.com/biden-georgia-senate-runoff-2000-stimulus-checks-immediately-2021-1?amp
#
# User #2 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #2 Note: Biden ran on $2,000 stimulus checks. To include the $600 sent by Trump as part of the $2,000 is misleading.     https://www.businessinsider.com/biden-georgia-senate-runoff-2000-stimulus-checks-immediately-2021-1?amp
#
#
#
#
# Tweet ID: 1358810121183330304
# Tweet Text:
# No, Rep. Maxine Waters didn’t say Trump supporters are "not welcome here" https://t.co/KaWVqnA8PH https://t.co/HVQMb6deR1
#
# User #1 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #1 Note: In &quot;the famous&quot; clip, Rep Waters is seen and heard threatening Trump staffers. https://www.cnn.com/2018/06/25/politics/maxine-waters-trump-officials/index.html     Later, she's quoted as saying: &quot;I did not threaten [Trump] constituents and supporters. I do that all the time, but I didn?t do it that time? https://thegreggjarrett.com/maxine-waters-says-she-threatens-trump-supporters-all-the-time/    I've given up on the fact checking sites.
#
# User #2 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #2 Note: She said, ?And if you see anybody from that Cabinet... you get out and you create a crowd. And you push back on them. And you tell them they're not welcome anymore, anywhere. We've got to get the children connected to their parents...&quot;    https://amp.cnn.com/cnn/2018/06/25/politics/maxine-waters-trump-officials/index.html
#
#
#
#
# Tweet ID: 1360695513100603394
# Tweet Text:
# white supremacy wins again
#
# User #1 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #1 Note: Over the past several years, Former President Trump has repeatedly disavowed and condemned white supremacy to the point that someone came up with a Supercut: https://youtu.be/SlOH_iKxPus He has said as much to the same reporters who appear to not understand and keep asking.     White supremacy will never win
#
# User #2 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #2 Note: White supremacy didn?t win. Truth, justice and democracy won. The senate voted, including Senator Tim Scott, and President Trump was acquitted.     https://amp.cnn.com/cnn/2021/02/13/politics/senate-impeachment-trial-day-5-vote/index.html
#
#
#
#
# Tweet ID: 1360607012111978497
# Tweet Text:
# Voting to acquit Donald Trump makes you a fascist.
#
# User #1 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #1 Note: The actual definition of Fascism is something different altogether.    Voting to acquit means that there was insufficient evidence to convict. Under the Bill of Rights, the accused is innocent until proven guilty. There was not enough to convict. And what existed was problematic.
#
# User #2 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #2 Note: The Senate followed the Constitution and voted to acquit the former president. Fascists wouldn?t vote, they would use dictatorial power to forcible suppress the opposition.     https://amp.cnn.com/cnn/2021/02/13/politics/senate-impeachment-trial-day-5-vote/index.html
#
#
#
#
# Tweet ID: 1361372791178674176
# Tweet Text:
# The American Rescue Plan will make vaccines free and accessible for everyone. We can't afford to wait. Congress needs to pass the American Rescue Plan. https://t.co/7pC5CasuLS
#
# User #1 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #1 Note: Per a 2020 post from the AARP, the COVID vaccines are already free: https://www.aarp.org/health/medicare-insurance/info-2020/cms-rule-makes-covid-19-vaccines-free.html
#
# User #2 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #2 Note: Per the CDC, currently vaccine doses purchased with U.S. taxpayer dollars will be given to the American people at no cost.     https://www.cdc.gov/coronavirus/2019-ncov/vaccines/faq.html
#
#
#
#
# Tweet ID: 1362594887808466944
# Tweet Text:
# Not only did Senator Ted Cruz &amp; his family abandon the people of #Texas for a vacation in #Cancun during the winter crisis; but they also abandoned their dog!
#
# #TedCruz #CancunCruz #FreeSnowflake
#
# https://t.co/oYOatVtseG
#
# User #1 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #1 Note: It appears that Ms. Ryan did not read the article. If she had, she would know that the security guard was taking care of the dog. Additionally, many posters have noted the lack of snow in the picture. It appears that Cruz's area got less snow than some parts of TX.
#
# User #2 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #2 Note: The dog was not abandoned. The headline is misleading. The security guard said he was taking care of the dog while the family was out of town.     https://nypost.com/2021/02/19/ted-cruz-left-pet-poodle-home-alone-during-cancun-trip-report/amp/
#
#
#
#
# Tweet ID: 1365724165626597379
# Tweet Text:
# Welcome back Mr President but first apologize for January 6th https://t.co/qCBEh1lYVj
#
# User #1 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #1 Note: In addition to the defense and acquittal factors surrounding the events of 6 Jan, COP Sund wrote an extensive letter discussing the day: https://static.foxnews.com/foxnews.com/content/uploads/2021/02/Letter_to_Congressional_leaders_02012021.pdf. Additionally, evidence continues to come to light that there were planned by several groups including John Sullivan's group.
#
# User #2 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #2 Note: Trump was acquitted. He did nothing wrong. Hence no reason to apologize.     https://abcnews.go.com/amp/Politics/president-donald-trump-acquitted/story?id=75853994
#
#
#
#
# Tweet ID: 1366251501518131201
# Tweet Text:
# Members of a large group, including adults, refused to wear masks as flight 2878 was preparing for departure from MIA-LGA. Repeated requests to comply with federal law necessitated their removal from the flight. The issue did not stem from a child under 2.
#
# User #1 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #1 Note: From news reports: https://t.co/Ov4Vf4ZWNo?amp=1 and videos posted on Twitter, it appears that the only person in the group NOT wearing a mask was the 18 month old. Maybe this would help: https://www.forbes.com/sites/forbesagencycouncil/2017/06/20/13-golden-rules-of-pr-crisis-management/?sh=4d9b4f481bcf
#
# User #2 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #2 Note: The flight was cancelled because an 18 month old was not wearing a mask. There is video of the incident.     https://nypost.com/2021/03/01/frontier-airlines-claims-large-group-of-maskless-passengers-disrupted-flight/amp/
#
#
#
#
# Tweet ID: 1395035775377551371
# Tweet Text:
# Column: The evidence is clear — COVID lockdowns saved lives without harming economies https://t.co/UJnmqTw3hw
#
# User #1 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #1 Note: Evidence says otherwise: carsey.unh.edu/COVID-19-Economic-Impact-By-State
#
# User #2 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #2 Note: Covid lockdowns significantly hurt the economy     https://www.economist.com/finance-and-economics/2021/01/13/what-is-the-economic-impact-of-the-latest-round-of-lockdowns    https://nypost.com/2021/05/01/covid-lockdowns-cost-jobs-dont-appear-to-have-saved-lives/amp/    Lockdowns did not save lives  https://www.wsj.com/amp/articles/do-lockdowns-save-many-lives-is-most-places-the-data-say-no-11587930911
#
#
#
#
# Tweet ID: 1414244444644077573
# Tweet Text:
# I know who killed Ashli Babbitt. He was impeached twice. https://t.co/ZpfgX5IveH
#
# User #1 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #1 Note: In addition to the fact that 45 was acquitted of both, there is evidence w John Sullivan?s brother implicating John as being involved in the death of this woman: https://youtu.be/sgEYRrvievE The brother claims John pushed her forward before she was shot ????     A true investigation is needed. Not politics.
#
# User #2 Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User #2 Note: USCP Lieutenant, Michael Byrd, Commander of the House Chamber, shot Ashli Babbitt.     https://www.tampafp.com/six-months-later-the-id-of-cop-who-killed-trump-supporter-ashli-babbit-has-come-to-light/    https://www.bhpioneer.com/naming-the-capitol-cop-who-killed-unarmed-jan-6-rioter-ashli-babbitt/article_2af763f7-8d33-56f6-81bc-3cb8826363f1.html

# %%
#users with no common tweets

no_common_users = [k for (k,v) in closest_users.items() if not v ]

for i in no_common_users:
    print(i)
    ind=pivot_table.index[i]

    df1 = notes_text_df_en[notes_text_df_en.participantId==ind]
    df1 = notes_df_two_noters[notes_df_two_noters.participantId==ind]
    
    common_text = pd.merge(df1,hydrated_Tweets,left_on='tweetId', right_on='id',how='inner')

    for _,x in common_text.iterrows():
        print(f'Tweet ID: {x.tweetId}')
        print(f'Tweet Text: {x.full_text_y}')
        print(f'User Classification: {x.classification}')
        print(f'User Note: {x.summary}')
        print()
# Out:
# 363
# Tweet ID: 1428065649536815104
# Tweet Text: If you want to add helpful context to any Tweet that might be misleading, open the ••• menu and then hit "Contribute to Birdwatch". Try it on this Tweet! https://t.co/fk57uFse7E
# User Classification: NOT_MISLEADING
# User Note: Test
#
# 406
# Tweet ID: 1418537677163483147
# Tweet Text: @ABC Only Hunter Biden can use the n word with no repercussions
# User Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User Note: Unproven bias from what seems to be a GOP supporter

# %%
# user with most common notes with other users
def user_with_most_common_notes_with_other_users(x):
    return sum(x[1].values())

i=max(closest_users.items(),key=user_with_most_common_notes_with_other_users)[0]
ind=pivot_table.index[i]


#df1 = notes_text_df_en[notes_text_df_en.participantId==ind]
df1 = notes_df_two_noters[notes_df_two_noters.participantId==ind]

common_text = pd.merge(df1,hydrated_Tweets,left_on='tweetId', right_on='id',how='inner')

for _,x in common_text.iterrows():
    print(f'Tweet ID: {x.tweetId}')
    print(f'Tweet Text: {x.full_text_y}')
    print(f'User Classification: {x.classification}')
    print(f'User Note: {x.summary}')
    print()
# Out:
# Tweet ID: 1433455893262348288
# Tweet Text: Last night, the Supreme Court officially overturned five decades of settled law and permitted Texas' unconstitutional abortion ban to stand.
#
# Yes: They gutted Roe v. Wade without hearing arguments, in a one-paragraph, unsigned 5-4 opinion issued in the middle of the night.
# User Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User Note: There is no criminal penalty under TX SB8.  It's a strictly civil issue and has no provisions for criminal prohibition, criminal consequences, or criminal penalties for having or performing an abortion.  Roe V Wade is untouched.  Just go read the law.
#
# Tweet ID: 1403077496296386561
# Tweet Text: Freedom of speech doesn't exist for Muslim women in Congress. The benefit of the doubt doesn't exist for Muslim women in Congress. House Democratic leadership should be ashamed of its relentless, exclusive tone policing of Congresswomen of color.
# User Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User Note: She is posting, via Twitter, that she is not being allowed freedom of speech, as a muslim woman, as an elected official, and as a US citizen.  On Twitter.  Link to sources?  Um, her tweet is literally right here.
#
# Tweet ID: 1436352232530792456
# Tweet Text: 1200 dead of COVID yesterday in Florida.
# Not the total for a week or a month, but ONE SINGLE DAY.
# User Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User Note: &quot;All but 19 of the newly reported deaths ? about 99% ? occurred since Aug. 11&quot;  https://www.miamiherald.com/news/coronavirus/article254107753.html
#
# Tweet ID: 1356458014853783552
# Tweet Text: My story isn’t the only story, nor is it the central story of what happened on Jan 6th.
#
# It is just one story of many of those whose lives were endangered at the Capitol by the lies, threats, and violence fanned by the cowardice of people who chose personal gain above democracy.
# User Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User Note: Everyone who works in the US Capitol is there for personal gain.  January 6th was no different.
#
# Tweet ID: 1354870146217746434
# Tweet Text: I'm constantly reminded of that awful Saturday morning 10 years ago when Gabby Giffords was shot. The GOP is playing with matches. More people will get hurt if they don't do something. https://t.co/nTJ6FWzFpz
# User Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User Note
# User Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User Note: Yes, this is an opinion piece, but the author presents 'what-if' as actual historical events.
#
# Tweet ID: 1359548463063646209
# Tweet Text: Interesting messaging from the CDC that previously told you not to wear a mask https://t.co/mpJrdOPXiO
# User Classification: NOT_MISLEADING
# User Note: At the beginning of the Pandemic, the WHO and the CDC both recommended against the general public using N95 particulate filter masks.  The CDC later altered their guidance to just 'mask' w/o any kind of standard for wear, construction, filtration, etc.  Masks should have standards
#
# Tweet ID: 1322254443644026880
# Tweet Text: I'm not going to shut down the country.
#
# I'm not going to shut down the economy.
#
# I'm going to shut down the virus.
# User Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User Note: This was a campaign &quot;promise&quot;.  It's nice to think it would happen, but it's only said to win elections, not for actual change.
#
# Tweet ID: 1354881668432191491
# Tweet Text: It’s time for a wealth tax in America.
# User Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User Note: The United States Tax Code doesn't distinguish between wealthy and poor.  In fact, the wealthy are taxed at a higher rate than others, and as such pay a far greater percent of taxes than 98% of the population.  https://www.taxpolicycenter.org/briefing-book/how-do-taxes-affect-income-inequality#:~:text=Because%20high%2Dincome%20households%20pay,over%20the%20past%2040%20years.
#
# Tweet ID: 1355313580120420353
# Tweet Text: I didn't move my office out of fear.
#
# I moved my office because I’m here to do a job for the people of St. Louis.
#
# What I cannot do is continue to look over my shoulder wondering if a white supremacist in Congress is conspiring against me and my team. Our focus is St. Louis. https://t.co/E5UWLr24qV
# User Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User Note: Her original statement said she was harassed, and was untrue, with video proof.  Her original statement said she was moving office for 'safety', which implies there was some reason to fear in her present location.  She continues to spread misinformation, if not direct lies.
#
# Tweet ID: 1356558043887116288
# Tweet Text: So Andy Ngô's out here deadnaming me and we're just gonna not even mention that disgusting transphobia, huh
# User Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User Note: Using slang and labels in an attempt to shame other people
#
# Tweet ID: 1358816627731673091
# Tweet Text: Republicans say we shouldn't be impeaching and convicting trump because he's not in office anymore, but we chased bin Laden for years and invaded a country that wasn't even involved in 9/11.
#
# January 6th was WORSE.
# Hold him accountable.
# User Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User Note: There is nothing comparable between September 11, 2001 and the demonstration in and around the US Capitol on January 6, 2021.  Not damage, not cost, not body count, nothing at all was comparable.
#
# Tweet ID: 1401006015898959877
# Tweet Text: "150 days since the worst single act of political violence since the Civil War, and the man who incited it is crying about being kept off social media." https://t.co/kUjLJGH6HP
# User Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User Note: Comparing a war between and within the US that claimed more lives than any other US conflict to a couple of hours where one woman was killed by a police officer is a false equivlancy and should not be forwarded by the media.  I'm not sharing a link because everyone knows this.
#
# Tweet ID: 1401213392216547328
# Tweet Text: 1/ A federal judge has overturned CA's three-decade-old ban on assault weapons, calling the law a “failed experiment” &amp; likening military-grade assault weapons to Swiss Army knives.
#
# Follow this 🧵 for a *thorough debunk* of the judge's infuriating ruling...
# User Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User Note: Repeatedly misrepresentation of 'facts', incorrect assessment of situation, and a poor general understanding of what it means when a law works and thus, does not work, does not make for a 'thorough debunk'.  It makes it thoroughly bunk, however.
#
# Tweet ID: 1412404201318146055
# Tweet Text: Call me crazy, but I think it should be easier to vote than it should be to buy a gun.
# User Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User Note: It is demonstrably false that it is easier to buy a gun than vote.  You do not need a background check to vote.  You do not have to buy a ballot to vote.  There is no mandatory training class to vote.  People do not try to ban ballots because of crime.
#
# Tweet ID: 1413203373420163075
# Tweet Text: Collapsed Surfside Condo Could Have Been Repaired Faster Under Repealed Fla. Law, Experts Say https://t.co/C3oLmiMHrw
# User Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User Note
# User Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User Note: Senator Paul had and has recovered from COVID19.  He repeatedly has tested negative for the virus, thus he cannot transmit the virus.  Wearing a mask would be theater, not science.  https://www.cnn.com/2020/04/07/politics/rand-paul-coronavirus-recovery/index.html
#
# Tweet ID: 1358432615741677569
# Tweet Text: ANTIFA is back on the streets of Washington DC causing mayhem.
#
# Last night, they chanted "if we don’t get it, burn it down" as they confronted police officers.
#
# ANTIFA is a domestic terrorist organization and should be declared as such. More to come on that!
# User Classification: NOT_MISLEADING
# User Note: Video proof of Antifa marching in DC  https://twitter.com/MrAndyNgo/status/1358216974749286401
#
# Tweet ID: 1358820709338865667
# Tweet Text: If you haven't been double masking, now's probably the time to start: We know at least the UK variant, which is more transmissible than other variants, is spreading rapidly. But there's a right way and a wrong way to do it: https://t.co/yxIKLUTqqW 1/x
# User Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User Note: There has been no established standard for 'mask' since the very beginning of COVID19 when everyone asked for citizens to stop buying all the N95 masks.  With no standard for construction, filtration, cleaning/reuse, what are you 'doubling'?
#
# Tweet ID: 1368109155479920640
# Tweet Text: 4 yr old: mummy I wish you could stop working forever and just play with us everyday
#
# Me: (feeling guilt) why did you ask me this and not your dad?
#
# 4 yr old: because he earns more money than you
#
# The awareness of gender pay gap starts young
#
# How’s your weekend going?
# User Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User Note: This is just plain false.  It's a verified account posting made up stories about woke preschool children.  It didn't happen.  It doesn't ever happen.
#
# Tweet ID: 1416804914379038727
# Tweet Text: A dangerous turn of events as Trump flirts with anti-vaccine sentiment. https://t.co/aQBd7Z3ilc
# User Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User Note: Nothing in the statement suggests that people should not be vaccinated. The fmr President is criticizing the lack of participation based on the past behaviors and past statements by the current administration.  This is literal misinformation, since it's not at all what was said
#
# Tweet ID: 1422309242044829701
# Tweet Text: The ATF still lacks a leader because of gun obsessives’ delusional oversensitivity, the Editorial Board writes https://t.co/pD3t7a0ChB
# User Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User Note: Believing a racist should not be in charge of government agencies is not a 'rightwing extremist' position.  So says the Washington Post  https://www.washingtonpost.com/education/2021/06/12/teachers-protest-laws-restricting-antiracism-lessons-in-school/
#
# Tweet ID: 1424516163804012548
# Tweet Text: The Miami outfielder was called n***** incessantly by a Rockies fan. https://t.co/JSPqugvPQU
# User Classification: MISINFORMED_OR_POTENTIALLY_MISLEADING
# User Note: False and misleading, incorrect information based on bias, not actual fact or investigation.  https://twitter.com/SteveStaeger/status/1424751806400323586

# %%
closest_users[i]
# Out:
# {1: 1,
#  5: 1,
#  11: 5,
#  16: 1,
#  47: 12,
#  57: 1,
#  62: 5,
#  63: 1,
#  67: 1,
#  82: 2,
#  84: 2,
#  91: 1,
#  93: 2,
#  94: 4,
#  104: 1,
#  108: 5,
#  111: 2,
#  112: 1,
#  124: 1,
#  131: 1,
#  135: 3,
#  137: 3,
#  149: 1,
#  164: 1,
#  174: 1,
#  177: 1,
#  184: 2,
#  187: 6,
#  190: 1,
#  215: 1,
#  223: 1,
#  224: 2,
#  226: 3,
#  231: 2,
#  234: 1,
#  237: 1,
#  252: 1,
#  266: 1,
#  272: 1,
#  275: 1,
#  292: 7,
#  298: 1,
#  299: 1,
#  301: 1,
#  311: 1,
#  312: 1,
#  330: 2,
#  335: 3,
#  341: 1,
#  366: 1,
#  367: 1,
#  369: 1,
#  377: 1,
#  380: 6,
#  384: 1,
#  400: 1,
#  408: 1,
#  411: 1,
#  421: 1,
#  423: 1,
#  426: 2,
#  431: 1,
#  441: 1,
#  448: 1,
#  460: 2,
#  466: 1,
#  468: 1,
#  474: 1,
#  475: 1,
#  486: 2,
#  492: 1,
#  494: 1,
#  524: 1,
#  527: 1,
#  535: 1,
#  549: 1,
#  580: 1,
#  589: 1,
#  596: 1,
#  602: 1,
#  627: 1,
#  632: 1,
#  649: 2,
#  653: 2,
#  663: 1,
#  666: 1,
#  667: 1,
#  697: 2,
#  712: 1,
#  714: 2,
#  737: 1,
#  756: 1,
#  759: 1,
#  769: 1,
#  770: 6,
#  777: 1,
#  784: 2,
#  788: 1,
#  798: 1,
#  799: 1,
#  807: 1,
#  809: 1,
#  814: 2,
#  821: 1,
#  822: 3,
#  824: 3,
#  826: 1,
#  835: 9,
#  837: 1,
#  843: 1,
#  851: 1,
#  867: 4,
#  878: 1,
#  887: 1,
#  897: 2,
#  906: 2,
#  909: 2,
#  925: 2,
#  938: 1,
#  955: 2,
#  960: 1,
#  966: 1,
#  967: 1,
#  968: 2,
#  974: 1,
#  977: 4,
#  981: 3,
#  984: 1,
#  992: 1,
#  999: 1,
#  1004: 3,
#  1005: 2,
#  1010: 1,
#  1011: 1,
#  1017: 1,
#  1021: 2,
#  1027: 1,
#  1031: 1,
#  1036: 1,
#  1045: 1,
#  1050: 2,
#  1063: 1,
#  1066: 1,
#  1075: 1,
#  1102: 1,
#  1112: 1,
#  1114: 2,
#  1117: 1,
#  1126: 2,
#  1127: 1,
#  1131: 1,
#  1143: 1,
#  1147: 1,
#  1165: 1,
#  1186: 2,
#  1195: 6,
#  1197: 1,
#  1220: 1,
#  1223: 1,
#  1233: 3,
#  1258: 1,
#  1274: 1,
#  1276: 1,
#  1288: 1,
#  1289: 1,
#  1300: 1,
#  1304: 3,
#  1307: 3,
#  1317: 2,
#  1318: 5,
#  1321: 1,
#  1322: 2,
#  1327: 1,
#  1329: 1,
#  1333: 1,
#  1334: 1,
#  1337: 1,
#  1338: 1,
#  1340: 2,
#  1343: 2,
#  1352: 1,
#  1374: 1,
#  1376: 1,
#  1377: 1,
#  1390: 1,
#  1393: 1,
#  1399: 1,
#  1405: 1,
#  1407: 2,
#  1412: 1,
#  1416: 1,
#  1423: 1,
#  1425: 1,
#  1428: 2,
#  1429: 1,
#  1436: 1,
#  1437: 1,
#  1440: 1,
#  1443: 1,
#  1445: 1,
#  1448: 1,
#  1462: 8,
#  1463: 2,
#  1476: 1,
#  1480: 1,
#  1487: 1,
#  1498: 1,
#  1504: 1,
#  1506: 1,
#  1520: 1,
#  1528: 1,
#  1530: 1,
#  1531: 1,
#  1537: 1,
#  1539: 1,
#  1541: 1,
#  1545: 1}

# %%
closest_users[1463]
# Out:
# {16: 1,
#  63: 1,
#  70: 1,
#  88: 1,
#  272: 2,
#  335: 1,
#  527: 1,
#  714: 1,
#  759: 1,
#  814: 1,
#  859: 1,
#  969: 1,
#  1078: 2,
#  1130: 1,
#  1194: 1,
#  1195: 1,
#  1297: 1,
#  1321: 1,
#  1436: 1,
#  1462: 1,
#  1470: 1,
#  1545: 1}

# %%
[i for i,x in enumerate(users[1463]) if x and users[1078][i]]
# Out:
# [648, 1024]

# %%
f=[]
for x in list(df1.tweetId):
    f.extend(list(notes_df_two_noters[notes_df_two_noters.tweetId==x].participantId))

# %%
len(set(f))
# Out:
# 218

# %%
len(closest_users[1078])
# Out:
# 217

# %%
def find_winner(x):
    x = Counter(x).items()
    m = max([xx[1] for xx in x ])
    return [xx[0] for xx in x if xx[1]==m]

# %%
c=0
n=0
for index,row in df1.iterrows():
    user_label=row.classification
    user_pid= row.participantId
    d = list(notes_df_two_noters[(notes_df_two_noters.tweetId==row.tweetId) & (notes_df_two_noters.participantId!=user_pid)]['classification'])
    winner = find_winner(d)
    if len(winner)==1:
        if winner[0]==user_label:
            c+=1
    n+=1

# %%
c/n
# Out:
# 0.8

# %%
#user with most notes

agg_count = notes_text_df_en.groupby('participantId')\
                .agg({'noteId':'count'})

ind = agg_count[agg_count.noteId==max(agg_count['noteId'])].index[0]

df1 = notes_text_df_en[notes_text_df_en.participantId==ind]
common_text = pd.merge(df1,hydrated_Tweets,left_on='tweetId', right_on='id',how='inner')
trump=0
covid = 0
for _,x in common_text.iterrows():

    if 'trump' in x.full_text_y.lower()+' '+x.summary or 'election' in x.full_text_y.lower()+' '+x.summary \
    or 'biden' in x.full_text_y.lower()+' '+x.summary:
        trump+=1
    elif 'covid' in x.full_text_y.lower()+' '+x.summary or 'pandemic' in x.full_text_y.lower()+' '+x.summary\
    or 'coronavirus' in x.full_text_y.lower()+' '+x.summary:
        covid+=1
    else:
        print(f'Tweet ID: {x.tweetId}')
        print(f'Tweet Text: {x.full_text_y}')
        print(f'User Note: {x.summary}')
        print()

print(f'US related tweets: {trump/len(common_text)*100}%')
# Out:
# Tweet ID: 1375893680515612677
# Tweet Text: We do not have a white supremacy problem in America. We do have a black culture problem. And it’s time we talk about it. https://t.co/Y381HA3A7d
# User Note: Violent white supremacists continue to be a real problem in the U.S.    FBI: &quot;What are Known Violent Extremist Groups?&quot;  https://www.fbi.gov/cve508/teen-website/what-are-known-violent-extremist-groups    &quot;White supremacy extremists are motivated by a hatred of other races and religions. Some try to achieve their political and social goals through violence.&quot;
#
# US related tweets: 71.34146341463415%

# %%
a=[]
pid=df1.iloc[0]['participantId']
for index,row in df1.iterrows():
    d=notes_text_df[(notes_text_df.tweetId==row.tweetId) & (notes_text_df.participantId!=pid)]
    a.append(len(d))

# %%
Counter(a)
# Out:
# Counter({1: 12, 2: 1, 0: 643})

# %%
#tweet with most notes
agg_notes=notes_text_df_en.groupby('tweetId')\
                .agg({'noteId':'count'})

ind = agg_notes[agg_notes.noteId==max(agg_notes.noteId)].index[0]


df1 = notes_text_df_en[notes_text_df_en.tweetId==ind]
common_text = pd.merge(df1,hydrated_Tweets,left_on='tweetId', right_on='id',how='inner')
s=[]

for _,x in common_text.iterrows():
    s.append(x.classification)
print(Counter(s))
# Out:
# Counter({'MISINFORMED_OR_POTENTIALLY_MISLEADING': 57, 'NOT_MISLEADING': 4})
